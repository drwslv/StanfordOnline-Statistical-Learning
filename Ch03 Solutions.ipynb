# %% [markdown]
# # Chapter 3 - Exercise Solutions

# %% [markdown]
# ## Conceptual

# %% [markdown]
# **(1)** Describe the null hypotheses to which the *p*-values given in Table 3.4 correspond. Explain what conclusions you can draw based on these *p*-values. Your explanation should be phrased in terms of `sales`, `TV`, `radio`, and `newspaper`, rather than in terms of the coefficients of the linear model.
#
# The null for each variable $H_0: \beta = 0$, meaning that the variable under consideration has no effect on `sales` (in the presense of the intercept and other variables specified).
#
# `intercept:` The *p*-value is significant, so when all variable are equal to zero, the expected value for `sales` is not likely to be 0, and in fact it is likely close to 2.939.
#
# `TV:` The *p*-value is significant, meaning, ceteris paribus, $\$1000$ (a one-unit increase) spent on TV advertising correspondds to $46$ additional units sold.
#
# `radio:` The *p*-value is significant, meaning, ceteris paribus, $\$1000$ (a one-unit increase) spent on radio advertising correspondds to $189$ additional units sold.
#
# `newspaper:` The *p*-value is *not* significant, meaning spending on newspaper advertising has no effect on additional units sold.

# %% [markdown]
# **(2)** Carefully explain the differences between the KNN classifier and KNN regression methods.
#
# **KNN classifier:** To estimate the class of a point ing space, the class of the $K$ nearest neighboring observations is considered, and the most prevalent class is used as a prediction for the class of the point of space under consideration.
#
# **KNN regression:** Similar to the KNN classifier, but for quantitative data. An estimate for $\hat{y}_i$ is found by considering the $K$ nearest neighbors to $x_i$ (for however many $x$s are included in the linear model), and averaging their values.

# %% [markdown]
# **(3)** Suppose we have a data set with five predictors, $X_1 = GPA$, $X_2 = IQ$, $X_3 = Level$ (1 for College and 0 for High School), $X_4 =$ Interaction between $GPA$ and $IQ$, and $X_5 =$ Interaction between $GPA$ and $Level$. The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get:
#
# $\hat{\beta}_0 = 50$, $\hat{\beta}_1 = 20$, $\hat{\beta}_2 = 0.07$, $\hat{\beta}_3 = 35$, $\hat{\beta}_4 = 0.01$, $\hat{\beta}_5 = -10$.
#
#
# - **(a)** Which answer is correct and why?
#
# ii. For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates.
#
# $\hat{\beta}_3 = 35$, so when $X_3 = 1$, i.e. the individual is college graduate, salary is $\$35$ higher than when $X_3 = 0$ (i.e. a high school graduate). However, the effect also depends on $\hat{\beta}_5$, which is negative, so the answer depends on the actual level of GPA. The answer is ambiguous.
#
# iii. For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates provided that the GPA is high enough.
#
# $\partial Salary / \partial Level = \hat{\beta}_3 + \hat{\beta}_5 GPA = 35 - 10 GPA$
#
# If GPA > 3.5, the effect of Level (college graduate) on salary is negative; if GPA < 3.5, the effect of Level (college gradaute) on salary is positive. So the statement is true; With GPA > 3.5 high school graduates earn more than college graduates.
#
#
# - **(b)** Predict the salary of a college graduate with IQ of 110 and a GPA of 4.0.
#
# $ Salary = \hat{\beta}_0 + \hat{\beta}_1 X_1 + \hat{\beta}_2 X_2 + \hat{\beta}_3 X_3 + \hat{\beta}_4 X_4 + \hat{\beta}_5 X_5 $
#
# $ Salary = 50 + 20 X_1 + 0.07 X_2 + \hat{\beta}_3 X_3 + \hat{\beta}_4 X_4 + \hat{\beta}_5 X_5 $
#
# $ Salary = 50 + 20 (4.0) + 0.07 (110) + 35 (1) + 0.01 (4.0)(110) - 10 (4.0)(1) $
#
# $ Salary = 50 + 80 + 7.7 + 35 + 4.4 - 40 $
#
# $ Salary = 137.1 $
#
#
# - **(c)** True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.
#
# "Small" should be interpreted relative to the measure of the variables. If average IQ is 100 and average GPA is 2, then the average interaction value is 200. Multiplied by the coefficient, the average effect at these values is 0.01 * 200 = 2. That is, a one point rise in IQ or GPA trnslates to an increase in 2 for salary. It may be small, but there is no evidence that the effect doesn't exist (false). To assess evidence of it's relevance, one should examine the resultin *p*-value from the estimate.

# %% [markdown]
# **(4)** I collect a set of data (*n* = 100 observations) containing a single predictor and a quantitative response. I then fit a linear regression model to the data, as well as a separate cubic regression, i.e.
#
# $ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + \beta_3 X^3 + \epsilon $
#
# - **(a)** Suppose that the true relationship between X and Y is linear, i.e. $ Y = \beta_0 + \beta_1 X + \epsilon $. Consider the training residual sum of squares (RSS) for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
# **The 3rd order model will have a lower RSS.** Fitting the 3rd-order model to the 1st-order will likely simply result in $ \beta_2 $ and $ \beta_3 $ being close to zero, and/or being insignificant. However, adding more variables can only reduce residuals, never increase them; therefore always improves fit.
#
# - **(b)** Answer (a) using test rather than training RSS.
#
# The 1st-order model will have a lower RSS. In real-world test data, likely the 3rd-order model will have worse fit than the 1st-order model.
#
# - **(c)** Suppose that the true relationship between X and Y is not linear, but we don’t know how far it is from linear. Consider the training RSS for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
# **The 3rd-order model will have a lower RSS.** Similar to the answer to (a), the RSS will always decrease with additional variables on training data.
#
# - **(d)** Answer (c) using test rather than training RSS.
#
# **Not enough information.** If the model is somewhat nonlinear, likely the 3rd-order model will perform better on real-world test data, but we can't know for sure.

# %% [markdown]
# **(5)** Consider the fitted values that result from performing linear regres- sion without an intercept. In this setting, the ith fitted value takes
# the form
#
# $ \hat{y}_i = x_i \hat{\beta}$
#
# where
#
# $ \hat{\beta} = \sum^{n}_{j=1} x_j y_j / \sum^{n}_{j=1} x^2_j $
#
# Show that we can write
#
# $ \hat{y}_i = \sum^{n}_{j=1} a_j y_j$
#
# What is $a_j$?
#
# *Note: We interpret this result by saying that the fitted values from linear regression are linear combinations of the response values.*

# %% [markdown]
# $ \hat{y}_i = x_i \sum^{n}_{j=1} x_j y_j / \sum^{n}_{k=1} x^2_k $
#
# $ \hat{y}_i = \sum^{n}_{j=1}  x_i x_j y_j / \sum^{n}_{k=1} x^2_k $
#
# $ \hat{y}_i = \sum^{n}_{j=1} ( x_i x_j  / \sum^{n}_{k=1} x^2_k ) y_j$
#
# $ a_j = x_i x_j  / \sum^{n}_{k=1} x^2_k $

# %% [markdown]
# **(6)** Using (3.4), argue that in the case of simple linear regression, the least squares line always passes through the point $(\bar{x}, \bar{y})$.
#
# (3.4) $\hat{\beta}_0 = \bar{y} - \hat{\beta}_1 \bar{x} $
#
# Regression line: $ y = \hat{\beta}_0 + \hat{\beta}_1 x $
#
# Substitute $ \bar{x} $ for $x$ and $ \bar{y} $ for $y$ and we have: $ \bar{y} = \hat{\beta}_0 + \hat{\beta}_1 \bar{x} $
#
# Substitute expression for $ \hat{\beta}_0 $ above: $ \bar{y} = \bar{y} - \hat{\beta}_1 \bar{x} + \hat{\beta}_1 \bar{x} $
#
# The term $ \hat{\beta}_1 \bar{x} $ cancels out, and it becomes evident that $ \bar{y} = \bar{y} $

# %% [markdown]
# **(7)** It is claimed in the text that in the case of simple linear regression of Y onto X, the $R^2$ statistic (3.17) is equal to the square of the correlation between X and Y (3.18). Prove that this is the case. For simplicity, you may assume that $ \bar{x} = \bar{y} = 0 $.
#
#
# $$ Cor(X, Y) = \frac{ \sum^n_{i=1} (x_i - \bar{x})(y_i - \bar{y})}{ \sqrt( \sum^n_{i=1} (x_i - \bar{x})^2 ) \sqrt( \sum^n_{i=1} (y_i - \bar{y})^2 )} $$
#
# $$ Cor(X, Y)^2 = \frac{ \sum^n_{i=1} (x_i - \bar{x})(y_i - \bar{y}) \sum^n_{i=1} (x_i - \bar{x})(y_i - \bar{y}) }{  \sum^n_{i=1} (x_i - \bar{x})^2  \sum^n_{i=1} (y_i - \bar{y})^2 } $$
#
# $$ Cor(X, Y)^2 = \frac{ \sum^n_{i=1} (x_i - \bar{x})(y_i - \bar{y}) \sum^n_{i=1} (x_i - \bar{x})(y_i - \bar{y}) }{  \sum^n_{i=1} (x_i - \bar{x})(x_i - \bar{x})  \sum^n_{i=1} (y_i - \bar{y})(y_i - \bar{y}) } $$
#
# Using assumption that $ \bar{x} = \bar{y} = 0 $
#
# $$ Cor(X, Y)^2 = \frac{ \sum^n_{i=1} x_i y_i \sum^n_{i=1} x_i y_i }{  \sum^n_{i=1} x_i x_i \sum^n_{i=1} y_i y_i } = \beta \frac{ \sum^n_{i=1} x_i y_i }{ \sum^n_{i=1} y_i y_i } $$
#
# $ \beta_0 = \bar{y} - \beta_1 \bar{x} = 0 $
#
# $$ R^2 = \frac{TSS - RSS}{TSS} = \frac{\sum^n_{i=1} y_i y_i - \sum^n_{i=1} (y_i - \hat{y}_i)^2}{\sum^n_{i=1} y_i y_i}$$
#
# $$ R^2 = \frac{\sum^n_{i=1} y_i y_i - \sum^n_{i=1} (y_i - \beta x_i)^2 }{\sum^n_{i=1} y_i y_i}$$
#
# $$ R^2 = \frac{\sum^n_{i=1} y_i^2 - \sum^n_{i=1} y_i^2 - 2 \beta y_i x_i + \beta^2 x_i^2 }{\sum^n_{i=1} y_i y_i}$$
#
# $$ R^2 = \frac{\sum^n_{i=1} y_i^2 - \sum^n_{i=1} y_i^2 + \sum^n_{i=1}  2 \beta y_i x_i - \beta^2 x_i^2 }{\sum^n_{i=1} y_i y_i}$$
#
# $$ R^2 = \beta ( \frac{ \sum^n_{i=1}  2 y_i x_i - \beta x_i^2 }{\sum^n_{i=1} y_i y_i} )$$
#
# $$ R^2 = \beta ( \frac{ \sum^n_{i=1}  2 y_i x_i }{\sum^n_{i=1} y_i y_i} - \frac{  \sum^n_{i=1} \beta x_i^2 }{\sum^n_{i=1} y_i y_i} )$$
#
# $$ R^2 = \beta ( \frac{ \sum^n_{i=1}  2 y_i x_i }{\sum^n_{i=1} y_i y_i} - \beta \frac{  \sum^n_{i=1}  x_i^2 }{\sum^n_{i=1} y_i y_i} )$$
#
# $$ R^2 = \beta ( \frac{ \sum^n_{i=1}  2 y_i x_i }{\sum^n_{i=1} y_i y_i} - \frac{ \sum^n_{i=1}  x_i y_i  \sum^n_{i=1}  x_i^2 }{ \sum^n_{i=1}  x_i^2 \sum^n_{i=1} y_i y_i} )$$
#
# $$ R^2 = \beta ( \frac{ \sum^n_{i=1}  2 y_i x_i }{\sum^n_{i=1} y_i y_i} - \frac{ \sum^n_{i=1}  x_i y_i }{ \sum^n_{i=1} y_i y_i} )$$
#
# $$ R^2 = \beta \frac{ \sum^n_{i=1}  x_i y_i }{\sum^n_{i=1} y_i y_i} = Cor(X, Y)^2 $$

# %% [markdown]
# ## Applied

# %% [markdown]
# ### (8)
#
# This question involves the use of simple linear regression on the `Auto` data set.
#
# **(a)** Use the `sm.OLS()` function to perform a simple linear regression with `mpg` as the response and `horsepower` as the predictor. Use the `summarize()` function to print the results. Comment on the output.

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)

# %%
Auto = load_data('auto')
Auto.head()
Auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
# Use shortcut to create Pandas dataframe
design = MS(['horsepower'])

X = design.fit_transform(Auto)

y = Auto['mpg']
model = sm.OLS(y, X)
results = model.fit()

print(results.summary())
# summarize(results)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           7.03e-81
# Time:                        11:30:25   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %% [markdown]
# **i.** Is there a relationship between the predictor and the response?
#
# Yes, it has a coefficient of -0.16 with the *p*-value < 0.000.

# %% [markdown]
# **ii.** How strong is the relationship between the predictor and the response?
#
# A one-unit increase in `horsepower` is associated with a 0.16 decline in `mpg`. The $R^2$ is 0.60, relatively strong.

# %% [markdown]
# **iii.** Is the relationship between the predictor and the response positive or negative?
#
# The relationship is negataive.

# %% [markdown]
# **iv.** What is the predicted `mpg` associated with a `horsepower` of 98? What are the associated 95 % confidence and prediction intervals?
#
# $ mpg = 39.94 -0.16 \cdot horsepower $
#
# $ mpg = 39.94 -0.16 \cdot 98 $

# %%
mpg = results.params[0] + results.params[1] * 98

print(f"The predicted vale for mpg is {mpg:.2f}.")
# Out:
# The predicted vale for mpg is 24.47.

# %% [markdown]
# Or, obtain the result using the `MS()` helper function:

# %%
X_predict = design.transform(pd.DataFrame({'horsepower':[98]}))
predictions = results.get_prediction(X_predict)
print(f"The predicted vale for mpg is {predictions.predicted_mean[0] :.2f}.")
# Out:
# The predicted vale for mpg is 24.47.

# %%
X_predict
# Out:
#    intercept  horsepower
# 0        1.0          98

# %% [markdown]
# 95% confidence interval:

# %%
predictions.conf_int(alpha=0.05)
# Out:
# array([[23.97307896, 24.96107534]])

# %% [markdown]
# 95% prediction interval:

# %%
predictions.conf_int(obs=True, alpha=0.05)
# Out:
# array([[14.80939607, 34.12475823]])

# %% [markdown]
# **(b)** Plot the response and the predictor in a new set of axes `ax`. Use the `ax.axline()` method or the `abline()` function defined in the lab to display the least squares regression line.

# %%
def abline(ax, b, m, *args, **kwargs):
    "Add a line with slope m and intercept b to ax"
    xlim = ax.get_xlim()
    ylim = [m * xlim[0] + b, m * xlim[1] + b] # predicted values for any particular set of x
    ax.plot(xlim, ylim, *args, **kwargs)

# %%
fig, ax = subplots(figsize=(8,4))
ax.scatter(X['horsepower'], y)
ax.set_xlabel('Horsepower')
ax.set_ylabel('MPG')
ax.axline( (X['horsepower'].mean(), y.mean() ), slope=results.params[1], color='r');
# abline(ax, results.params[0], results.params[1], 'r--') # SAME

# %% [markdown]
# **(c)** Produce some of diagnostic plots of the least squares regression fit as described in the lab. Comment on any problems you see with the fit.

# %%
fig, ax = subplots(figsize=(8,4))
ax.scatter(results.fittedvalues, results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='black', ls='--')

poly_eqn = np.poly1d( np.polyfit(results.fittedvalues, results.resid, 2) )
y_poly = poly_eqn(results.fittedvalues)

# Sort x, y for fitted line
sorted_indices = sorted(range(len(results.fittedvalues)), key=lambda i: results.fittedvalues[i])
x_sorted = [results.fittedvalues[i] for i in sorted_indices]
y_sorted = [y_poly[i] for i in sorted_indices]

ax.plot(x_sorted, y_sorted, c='r');

# %% [markdown]
# There is unequal variance in the error term (heteroscedasticity)

# %% [markdown]
# ### (9)

# %% [markdown]
# This question involves the use of multiple linear regression on the `Auto` data set.
#
# **(a)** Produce a scatterplot matrix which includes all of the variables in the data set.

# %%
Auto = load_data('auto')
# Auto.head()
# Auto.dtypes

# %%
pd.plotting.scatter_matrix(Auto, figsize=(12,12));

# %% [markdown]
# **(b)** Compute the matrix of correlations between the variables using the `DataFrame.corr()` method.

# %%
Auto.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %% [markdown]
# **(c)** Use the `sm.OLS()` function to perform a multiple linear regression with `mpg` as the response and all other variables except `name` as the predictors. Use the `summarize()` function to print the results. Comment on the output.

# %%
terms = Auto.columns.drop(['mpg','name'])
terms
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'year', 'origin'],
#       dtype='object')

# %%
# Use shortcut to create Pandas dataframe
design = MS(terms)
X = design.fit_transform(Auto)

y = Auto['mpg']

model = sm.OLS(y, X)
results = model.fit()

print(results.summary())
# summarize(results)

# Second model: regression intercept only; for comparison in anova_lm
X2 = X['intercept']
model2 = sm.OLS(y, X2)
results2 = model2.fit()
summarize(results2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):          2.04e-139
# Time:                        15:31:23   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept      -17.2184      4.644     -3.707      0.000     -26.350      -8.087
# ...

# %% [markdown]
# **i.** Is there a relationship between the predictors and the response? Use the `anova_lm()` function from statsmodels to answer this question.
#
# `anova_lm()` is good for computing the F-test; especially in testing only a subset of predictors.

# %%
anova_lm(results2, results) # ORDER MATTERS (restricted, unrestricted)
# Out:
#    df_resid           ssr  df_diff       ss_diff           F         Pr(>F)
# 0     391.0  23818.993469      0.0           NaN         NaN            NaN
# 1     384.0   4252.212530      7.0  19566.780939  252.428045  2.037106e-139

# %% [markdown]
# **ii.** Which predictors appear to have a statistically significant relationship to the response?
#
# `intercept`, `displacement`, `weight`, `year`, `origin`

# %% [markdown]
# **iii.** What does the coefficient for the year variable suggest?
#
# For each addition year of the car (each year more recent), `mpg` increases by 0.75.

# %% [markdown]
# **(d)** Produce some of diagnostic plots of the linear regression fit as described in the lab. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?

# %%
# Regression of y on yhat to get coefficient -- turns out it's always 1
results_yhat = sm.OLS(y, results.fittedvalues).fit()
results_yhat.summary()
summarize(results_yhat)
# Out:
#     coef  std err        t  P>|t|
# x1   1.0    0.007  147.016    0.0

# %%
# Fitted line plot
fig, ax = subplots(figsize=(8,4))
ax.scatter(results.fittedvalues, y)
ax.set_xlabel('Y^')
ax.set_ylabel('MPG')
ax.axline( (results.fittedvalues.mean(), y.mean() ), slope=results_yhat.params[0], color='r');

# %%
# Residual plot
fig, ax = subplots(figsize=(8,4))
ax.scatter(results.fittedvalues, results.resid)
ax.set_xlabel('Fitted value')
ax.set_ylabel('Residual')
ax.axhline(0, c='black', ls='--')

poly_eqn = np.poly1d( np.polyfit(results.fittedvalues, results.resid, 2) )
y_poly = poly_eqn(results.fittedvalues)

# Sort x, y for fitted line
sorted_indices = sorted(range(len(results.fittedvalues)), key=lambda i: results.fittedvalues[i])
x_sorted = [results.fittedvalues[i] for i in sorted_indices]
y_sorted = [y_poly[i] for i in sorted_indices]

ax.plot(x_sorted, y_sorted, c='r');

# %% [markdown]
# There is considerable heteroscedastcity in the residuals; they form a non-linear pattern.

# %%
# Leverage plot
infl = results.get_influence()
fig, ax = subplots(figsize=(8,4))
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# 13

# %% [markdown]
# There is an outlier with high leverage at index 13.

# %% [markdown]
# **(e)** Fit some models with interactions as described in the lab. Do any interactions appear to be statistically significant?

# %%
termsInteract = list(terms) + [('displacement','horsepower')] + [('horsepower','weight')]
termsInteract
# Out:
# ['cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'year',
#  'origin',
#  ('displacement', 'horsepower'),
#  ('horsepower', 'weight')]

# %%
designInteract = MS(termsInteract)
XInteract = designInteract.fit_transform(Auto)

resultsInteract = sm.OLS(y, XInteract).fit()

print(resultsInteract.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     273.7
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):          1.46e-160
# Time:                        18:00:09   Log-Likelihood:                -967.65
# No. Observations:                 392   AIC:                             1955.
# Df Residuals:                     382   BIC:                             1995.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# intercept                   1.3639      4.476      0.305      0.761      -7.436      10.164
# ...

# %% [markdown]
# Interactions between `displacmeent` and `horsepower`, and between `horsepower` and `weight`, are both very significant!

# %% [markdown]
# **(f)** Try a few different transformations of the variables, such as $ \log(X) $, $ \sqrt(X) $, $ X^2 $. Comment on your findings.

# %%
Xnonlin = X.copy()
Xnonlin['displacement2'] = Xnonlin['displacement']**2
Xnonlin['weight2'] = Xnonlin['weight']**2
Xnonlin['horsepower2'] = Xnonlin['horsepower']**2

model = sm.OLS(y, Xnonlin)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     244.8
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):          4.35e-159
# Time:                        17:49:39   Log-Likelihood:                -968.23
# No. Observations:                 392   AIC:                             1958.
# Df Residuals:                     381   BIC:                             2002.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# intercept         3.5087      4.789      0.733      0.464      -5.908      12.925
# ...

# %% [markdown]
# ### (10)

# %% [markdown]
# This question should be answered using the `Carseats` data set.
#
# **(a)** Fit a multiple regression model to predict `Sales` using `Price`, `Urban`, and `US`.

# %%
Carseats = load_data('carseats')
Carseats.head()
# Carseats.dtypes
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
Carseats['ShelveLoc'].unique()
# Out:
# array(['Bad', 'Good', 'Medium'], dtype=object)

# %%
# Issues a warning:
# Carseats['UrbanB'] = 0
# Carseats['UrbanB'][ Carseats['Urban'] == 'Yes'] = 1

Carseats['UrbanBin'] = Carseats['Urban'].apply(lambda x: 1 if x == 'Yes' else 0)
Carseats['USBin'] = Carseats['US'].apply(lambda x: 1 if x == 'Yes' else 0)
# Carseats

# %%
terms = ['Price', 'UrbanBin', 'USBin']
# terms

# %%
# design = MS(terms)
# X = design.fit_transform(Carseats)

# y = Carseats['Sales']

# model = sm.OLS(y, X)
# results = model.fit()


# Native code
model = smf.ols(formula='Sales ~ Price + UrbanBin + USBin',data=Carseats)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           2.39e-23
# Time:                        11:24:17   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0435      0.651     20.036      0.000      11.764      14.323
# ...

# %% [markdown]
# **(b)** Provide an interpretation of each coefficient in the model. Be careful — some of the variables in the model are qualitative!
#
# `Price:` A $1 increase in `price` is associated with a $54.50  *decline* in `sales` (`sales` is in $1000 units, price is in $1 units).
#
# `Urban:` Stores in urban locations have on average $21.90 lower sales. However, this coefficient is not significant.
#
# `US:` Stores in teh US have on average $1200.60 higher sales.

# %% [markdown]
# **(c)** Write out the model in equation form, being careful to handle the qualitative variables properly.
#
# $ Sales = \beta_0 + \beta_1 \cdot Price + \beta_2 \cdot Urban + \beta_3 \cdot US + \epsilon $
#
# $ Sales = 13.04 - 0.0545 \cdot Price - 0.0219 \cdot Urban + 1.20 \cdot US + \epsilon$, when Urban = 1 and US = 1
#
# $ Sales = 13.04 - 0.0545 \cdot Price + \epsilon$, when Urban = 0 and US = 0, etc.

# %% [markdown]
# **(d)** For which of the predictors can you reject the null hypothesis $H_0 :β_j = 0 $ ?
#
# I can reject it for `Intercept`, `Price`, and `US`.``

# %% [markdown]
# **(e)** On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.

# %%
model = smf.ols(formula='Sales ~ Price + USBin',data=Carseats)
results2 = model.fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           2.66e-24
# Time:                        11:24:19   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...

# %% [markdown]
# **(f)** How well do the models in (a) and (e) fit the data?

# %% [markdown]
# They both have an $R^2$ of 0.239. The reduced model has a higher overall F-statistic.

# %%
anova_lm(results2, results)
# Out:
#    df_resid          ssr  df_diff  ss_diff         F    Pr(>F)
# 0     397.0  2420.874462      0.0      NaN       NaN       NaN
# 1     396.0  2420.834671      1.0  0.03979  0.006509  0.935739

# %% [markdown]
# **(g)** Using the model from (e), obtain 95% confidence intervals for the coefficient(s).

# %%
print(f"Intercept:", {results2.params[0] - 1.96**results2.bse[0]}, {results2.params[0] + 1.96*results2.bse[0]})
print(f"Price:", {results2.params[1] - 1.96**results2.bse[1]}, {results2.params[1] + 1.96*results2.bse[1]})
print(f"US:", {results2.params[2] - 1.96**results2.bse[2]}, {results2.params[2] + 1.96*results2.bse[2]})
# Out:
# Intercept: {11.501795671847892} {14.267506317698462}
# Price: {-1.0580034176822164} {-0.04422658608172723}
# US: {0.009670774685461847} {1.7062265544027295}

# %%
results2.conf_int()
# Out:
#                   0          1
# Intercept  11.79032  14.271265
# Price      -0.06476  -0.044195
# USBin       0.69152   1.707766

# %% [markdown]
# **(h)** Is there evidence of outliers or high leverage observations in the model from (e)?

# %%
outliers = results2.outlier_test(method='bonf', alpha=0.05)
outliers
outliers.loc[ outliers['bonf(p)'] < 1 , : ] # No ouliters, no p-values below 1
# Out:
# Empty DataFrame
# Columns: [student_resid, unadj_p, bonf(p)]
# Index: []

# %%
# Leverage plot
infl = results2.get_influence()
fig, ax = subplots(figsize=(8,4))
ax.scatter(np.arange(Carseats.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
np.argmax(infl.hat_matrix_diag)
# Out:
# 42

# %% [markdown]
# ### (11)

# %% [markdown]
# In this problem we will investigate the t-statistic for the null hypothesis $ H_0: \beta = 0 $ in simple linear regression without an intercept. To begin, we generate a predictor x and a response y as follows.

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

# %% [markdown]
# **(a)** Perform a simple linear regression of `y` onto `x`, *without* an intercept. Report the coefficient estimate $ \hat{\beta} $, the standard error of this coefficient estimate, and the *t*-statistic and *p*-value associated with the null hypothesis $ H_0: \beta = 0 $. Comment on these results. (You can perform regression without an intercept using the keywords argument `intercept=False` to `ModelSpec()`.)

# %%
X = pd.DataFrame({'x': x})

design = MS('x', intercept=False)
X = design.fit_transform(X)

y = pd.DataFrame({'y': y})

model = sm.OLS(y, X)
results = model.fit()

print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):                    6.23e-31
# Time:                        13:45:45   Log-Likelihood:                         -141.35
# No. Observations:                 100   AIC:                                      284.7
# Df Residuals:                      99   BIC:                                      287.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model2 = smf.ols(formula='y ~ x - 1', data=X)
results2 = model2.fit()
print(results2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):                    6.23e-31
# Time:                        13:45:54   Log-Likelihood:                         -141.35
# No. Observations:                 100   AIC:                                      284.7
# Df Residuals:                      99   BIC:                                      287.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Coefficient: 1.9762, very close to the true value of 2
#
# Standard error: 0.117
#
# *t*-statistic: 16.898
#
# *p*-value: < 0.000, very significant

# %% [markdown]
# **(b)** Now perform a simple linear regression of `x` onto `y` without an intercept, and report the coefficient estimate, its standard error, and the corresponding *t*-statistic and *p*-values associated with the null hypothesis $ H_0: \beta = 0 $. Comment on these results.

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

Y = pd.DataFrame({'y': y})

design = MS('y', intercept=False)
Y = design.fit_transform(Y)

x = pd.DataFrame({'x': x})

model = sm.OLS(x, Y)
results = model.fit()

print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):                    6.23e-31
# Time:                        13:54:24   Log-Likelihood:                         -58.349
# No. Observations:                 100   AIC:                                      118.7
# Df Residuals:                      99   BIC:                                      121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

df = pd.DataFrame({'y': y, 'x':x})

model3 = smf.ols(formula='x ~ y - 1', data=df)
results3 = model3.fit()
print(results3.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):                    6.23e-31
# Time:                        13:55:20   Log-Likelihood:                         -58.349
# No. Observations:                 100   AIC:                                      118.7
# Df Residuals:                      99   BIC:                                      121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Coefficient: 0.3757, very close to the true value of 0.5
#
# Standard error: 0.022
#
# *t*-statistic: 16.898 (same as earlier)
#
# *p*-value: < 0.000 (same as earlier)

# %% [markdown]
# **(c)** What is the relationship between the results obtained in (a) and (b)?
#
# The coefficient in (b) is roughly inverse of that in (a). The *t*-statistic and *p*-value are identical in both regressions.

# %% [markdown]
# **(d)** For the regression of `Y` onto `X` without an intercept, the *t*-statistic for $ H_0: \beta = 0 $ takes the form $ \hat{\beta} / SE(\hat{\beta}) $, where $ \hat{\beta} $ is given by (3.38), and where
#
# $$ SE(\hat{\beta}) = \sqrt{ \frac{ \sum^n_{i=1} (y_i - x_i \hat{\beta})^2 } { (n-1)  \sum^n_{j=1} x_j^2 }  } $$
#
# (These formulas are slightly different from those given in Sec- tions 3.1.1 and 3.1.2, since here we are performing regression without an intercept.) Show algebraically, and confirm numerically in Python, that the *t*-statistic can be written as
#
# $$ t = \frac{ \sqrt{n-1} \sum^n_{i=1} x_i y_i } { \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{j=1} y_j^2  -  ( \sum^n_{j=1} x_i y_j )^2  } }     $$

# %% [markdown]
# (Omitting the ^ over $\hat{\beta}$ for simplicity)
#
# $$ t = \frac{\beta} {SE(\beta)} $$
#
# Using $ \bar{x} = \bar{y} = 0 $ and
#
# $$ \beta = \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } $$
#
# $$ t = \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } \frac{ \sqrt{ (n-1)  \sum^n_{j=1} x_j^2 } }{ \sqrt{ \sum^n_{i=1} (y_i - x_i \hat{\beta})^2 } } $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } \frac{ \sqrt{   \sum^n_{j=1} x_j^2 } }{ \sqrt{ \sum^n_{i=1} (y_i - x_i \hat{\beta})^2 } } $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ \sqrt{   \sum^n_{j=1} x_j^2 } }{ \sqrt{  (\sum^n_{i=1} x_i^2) ^2   }   \sqrt{ \sum^n_{i=1} (y_i - x_i \hat{\beta})^2 } } $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  } \sqrt{ \sum^n_{i=1} (y_i - x_i \hat{\beta})^2 } } $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2 \sum^n_{i=1} ( y_i^2 - 2 x_i y_i \beta + x_i^2 \beta^2 )} } $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2 ( \sum^n_{i=1}  y_i^2 -  \sum^n_{i=1} 2 x_i y_i \beta +  \sum^n_{i=1} x_i^2 \beta^2 } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2 ( \sum^n_{i=1}  y_i^2 -   \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 }  \sum^n_{i=1} 2 x_i y_i       +  \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 }    \sum^n_{i=1} x_i^2  } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 -  \sum^n_{i=1} x_i^2 \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 }    \sum^n_{i=1} 2 x_i y_i       + \sum^n_{i=1} x_i^2  \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 }    \sum^n_{i=1} x_i^2  } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 -  \sum^n_{i=1} x_i y_i     \sum^n_{i=1} 2 x_i y_i       + \sum^n_{i=1} x_i^2  \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 } \frac{\sum^n_{i=1} x_i y_i } {\sum^n_{i=1} x_i^2 }    \sum^n_{i=1} x_i^2  } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 -  \sum^n_{i=1} x_i y_i     \sum^n_{i=1} 2 x_i y_i       + \frac{\sum^n_{i=1} x_i y_i } {1 } \frac{\sum^n_{i=1} x_i y_i } { 1 }    } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 - 2 \sum^n_{i=1} (x_i y_i)^2    + \sum^n_{i=1} x_i y_i  \sum^n_{i=1} x_i y_i   } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 - 2 \sum^n_{i=1} (x_i y_i)^2    +  \sum^n_{i=1} (x_i y_i)^2   } )} $$
#
# $$ t = \frac{ \sqrt{(n-1)} \sum^n_{i=1} x_i y_i } { 1 } \frac{ 1 }{ \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{i=1}  y_i^2 -  \sum^n_{i=1} (x_i y_i)^2   } )} $$
#
# $$ t = \frac{ \sqrt{n-1} \sum^n_{i=1} x_i y_i } { \sqrt{ \sum^n_{i=1} x_i^2  \sum^n_{j=1} y_j^2  -  ( \sum^n_{j=1} x_i y_j )^2  } }     $$

# %%
# SE
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

n = y.shape[0]

se_numerator = ((y - x* results2.params[0])**2).sum()

se_denominator = (n - 1) * ((x**2).sum())

se = np.sqrt( se_numerator / se_denominator)

print(f"Standard error: {se: 0.3f}, the same as in the above estimate.")

t_numerator = np.sqrt(n-1) * ((x * y).sum())

t_denominator = np.sqrt(  (x**2).sum() * (y**2).sum() - (  (x*y).sum() )**2 )

t = t_numerator / t_denominator

print(f"t-statistic: {t: 0.3f}, the same as in the above estimate.")
# Out:
# Standard error:  0.117, the same as in the above estimate.
# t-statistic:  16.898, the same as in the above estimate.

# %% [markdown]
# **(e)** Using the results from (d), argue that the t-statistic for the re- gression of y onto x is the same as the t-statistic for the regression of x onto y.
#
# In the formula for *t* in terms of `y` and `x`, we can see that `y` and `x` are completely interchangeable: they have te same transforms, and are mutually multiplied by one another, in both the numerator and denominator. If we simply switch `x` and `y` in the regression, the equation for *t* remains unchanged.

# %% [markdown]
# **(f)** In Python, show that when regression is performed with an intercept, the *t*-statistic for $ H_0: \beta_1 = 0 $ is the same for the regression of y onto x as it is for the regression of x onto y.

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = 2 * x + rng.normal(size=100)

df = pd.DataFrame({'y': y, 'x':x})

model_int_yx = smf.ols(formula='y ~ x', data=df)
results_int_yx = model_int_yx.fit()
print(results_int_yx.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     280.0
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           1.74e-30
# Time:                        15:13:55   Log-Likelihood:                -141.06
# No. Observations:                 100   AIC:                             286.1
# Df Residuals:                      98   BIC:                             291.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0760      0.101     -0.756      0.451      -0.276       0.124
# ...

# %%
model_int_xy = smf.ols(formula='x ~ y', data=df)
results_int_xy = model_int_xy.fit()
print(results_int_xy.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     280.0
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):           1.74e-30
# Time:                        15:14:12   Log-Likelihood:                -58.325
# No. Observations:                 100   AIC:                             120.6
# Df Residuals:                      98   BIC:                             125.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0095      0.044      0.216      0.829      -0.078       0.097
# ...

# %% [markdown]
# Note that the *t*-statistics are identical!

# %% [markdown]
# ### (12)

# %% [markdown]
# This problem involves simple linear regression without an intercept.
#
# **(a)** Recall that the coefficient estimate $ \hat{\beta} $ for the linear regression of Y onto X without an intercept is given by (3.38). Under what circumstance is the coefficient estimate for the regression of X onto Y the same as the coefficient estimate for the regression of Y onto X?
#
# The coefficient is the same when $ \hat{\beta} = 1/ \hat{\beta} $, so when $ \hat{\beta} = 1, -1 $.
#
# This is true when $ Cor(X,Y) = 1, -1 $, and because
#
# $$ Cor(X,Y) = \frac{Cov(X,Y)}{\sigma_X \sigma_Y} $$
#
# this will be true when
#
# $$ Cov(X,Y) = \sigma_X \sigma_Y $$
#
# Or from the equation
#
# $$ Cor(X,Y) = \frac{ \sum^n_{i=1} (x_i - \bar{x}) (y_i - \bar{y})  }{ \sqrt{ \sum^n_{i=1}  ( x_i - \bar{x}  )^2 }  \sqrt{ \sum^n_{i=1}  ( y_i - \bar{y}  )^2  }  } $$
#
# implies
#
# $$ \sum^n_{i=1} (x_i - \bar{x}) (y_i - \bar{y})  =  \sqrt{ \sum^n_{i=1}  ( x_i - \bar{x}  )^2 }  \sqrt{ \sum^n_{i=1}  ( y_i - \bar{y}  )^2  }       $$
#
# $$ \beta = \frac{ \sum^n_{i=1} (x_i - \bar{x}) (y_i - \bar{y}) }{ \sum^n_{i=1} (x_i - \bar{x})^2  } = \frac{ \sqrt{ \sum^n_{i=1}  ( x_i - \bar{x}  )^2 }  \sqrt{ \sum^n_{i=1}  ( y_i - \bar{y}  )^2  }  }{ \sum^n_{i=1} (x_i - \bar{x})^2  }     $$
#
# $$ \beta = \frac{  \sqrt{ \sum^n_{i=1}  ( y_i - \bar{y}  )^2  }  }{  \sqrt{ \sum^n_{i=1}  ( x_i - \bar{x}  )^2 }  }     $$
#
# If $ \bar{y} = \bar{x} = 0 $ (which should be true of regressing without an intercept)$
#
# $$ \beta = \frac{  \sqrt{ \sum^n_{i=1}  y_i^2  }  }{  \sqrt{ \sum^n_{i=1}  x_i^2 }  }     $$
#
# $ \beta $ must be = 1, so
#
# $$ \sum^n_{i=1} x_i^2 =  \sum^n_{i=1} y_i^2 $$
#
# Better version:
#
# $$ \beta_x = \frac{ \sum^n_{i=1} x_i y_i }{ \sum^n_{i=1} x_i^2  } = \beta_y = \frac{ \sum^n_{i=1} x_i y_i }{ \sum^n_{i=1} y_i^2  } $$
#
# This is true when
#
# $$ \sum^n_{i=1} x_i^2 =  \sum^n_{i=1} y_i^2 $$
#
# SO, THE TRUE SOLUTON $ \beta = 1 $ FOR TRUE BETA, but $ \hat{\beta} $ can actually be symmetrical for many estimates. It just won't be significant if not close to 1, it seems (becuase it's a bad estimate of the true value).

# %% [markdown]
# **(b)** Generate an example in Python with n = 100 observations in which the coefficient estimate for the regression of X onto Y is different from the coefficient estimate for the regression of Y onto X.

# %%
rng2 = np.random.default_rng(102)
x = rng2.normal(size=100)
yb = 2 * x + rng2.normal(size=100)

df = pd.DataFrame({'yb': yb, 'x':x})

model_int_yb_x = smf.ols(formula='yb ~ x -1', data=df)
results_int_yb_x = model_int_yb_x.fit()
print(results_int_yb_x.summary())

model_int_x_yb = smf.ols(formula='x ~ yb -1', data=df)
results_int_x_yb = model_int_x_yb.fit()
print(results_int_x_yb.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     yb   R-squared (uncentered):                   0.827
# Model:                            OLS   Adj. R-squared (uncentered):              0.826
# Method:                 Least Squares   F-statistic:                              474.2
# Date:                Sun, 10 Dec 2023   Prob (F-statistic):                    1.55e-39
# Time:                        23:10:09   Log-Likelihood:                         -142.86
# No. Observations:                 100   AIC:                                      287.7
# Df Residuals:                      99   BIC:                                      290.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# **(c)** Generate an example in Python with n = 100 observations in which the coefficient estimate for the regression of X onto Y is the same as the coefficient estimate for the regression of Y onto X.

# %%
rng2 = np.random.default_rng(1001)
x = rng2.normal(size=1000)

y_unsort = x.copy()
yb = y_unsort.copy()
np.random.shuffle(yb)

df = pd.DataFrame({'yb': yb, 'x':x})

model_int_yb_x = smf.ols(formula='yb ~ x -1', data=df)
results_int_yb_x = model_int_yb_x.fit()
print(results_int_yb_x.summary())

model_int_x_yb = smf.ols(formula='x ~ yb -1', data=df)
results_int_x_yb = model_int_x_yb.fit()
print(results_int_x_yb.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     yb   R-squared (uncentered):                   0.005
# Model:                            OLS   Adj. R-squared (uncentered):              0.004
# Method:                 Least Squares   F-statistic:                              4.966
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):                      0.0261
# Time:                        00:15:59   Log-Likelihood:                         -1413.0
# No. Observations:                1000   AIC:                                      2828.
# Df Residuals:                     999   BIC:                                      2833.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### (13)

# %% [markdown]
# In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use the default random number generator with seed set to 1 prior to starting part (a) to ensure consistent results.

# %%
rng = np.random.default_rng(1)

# %% [markdown]
# **(a)** Using the `normal()` method of your random number generator, create a vector, `x`, containing 100 observations drawn from a $ N(0,1) $ distribution. This represents a feature, X.

# %%
x = rng.normal(0, 1, size=100)

# %% [markdown]
# **(b)** Using the `normal()` method, create a vector, `eps`, containing 100 observations drawn from a $ N(0,0.25) $ distribution - a normal distribution with mean zero and variance 0.25.

# %%
eps = rng.normal(0, 0.25, size=100)

# %% [markdown]
# **(c)** Using `x` and `eps`, generate a vector `y` according to the model
#
# $$ y = -1 + 0.5 \cdot x + \epsilon $$
#
# (3.39) What is the length of the vector `y`? What are the values of $ \beta_0 $ and $ \beta_1 $ in this linear model?
#
# $ y $ is also of length 100. $ \beta_0  = -1 $ and $ \beta_1 = 0.5 $.

# %%
y = -1 + 0.5 * x + eps

# %% [markdown]
# **(d)** Create a scatterplot displaying the relationship between `x` and `y`. Comment on what you observe.

# %%
fig, ax = subplots(figsize = (5, 5))
ax.scatter(x, y)
ax.set_ylabel('y')
ax.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# Roughly a linear relationship, apparently normal distribution of error terms around $ \hat{y} $.

# %% [markdown]
# **(e)** Fit a least squares linear model to predict `y` using `x`. Comment on the model obtained. How do $ \hat{\beta_0} $ and $ \hat{\beta_1} $ compare to $ \beta_0 $ and $ \beta_1 $?

# %%
df = pd.DataFrame({'y': y, 'x':x})

model13 = smf.ols(formula='y ~ x', data=df)
results13 = model13.fit()
print(results13.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     456.4
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           1.17e-38
# Time:                        12:43:10   Log-Likelihood:                 5.8375
# No. Observations:                 100   AIC:                            -7.675
# Df Residuals:                      98   BIC:                            -2.465
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0405      0.023    -45.004      0.000      -1.086      -0.995
# ...

# %%
print(f"The intercept is {results13.params[0]:.2f} and the slope is {results13.params[1]:.2f}, very close to the true values of -1 and 0.5, respectively.")
# Out:
# The intercept is -1.04 and the slope is 0.50, very close to the true values of -1 and 0.5, respectively.

# %% [markdown]
# **(f)** Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the `legend()` method of the axes to create an appropriate legend.

# %%
fig, ax = subplots(figsize = (5, 5))
ax.scatter(x, y)
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.axline( (x.mean(), y.mean()) , slope = results13.params[1], color = 'r', label = 'Estimated')
ax.axline( (0, -1) , slope = 0.5, color = 'k', linestyle = '--', label = 'True')
ax.legend(loc="lower right");

# %% [markdown]
# **(g)** Now fit a polynomial regression model that predicts `y` using `x` and `x^2`. Is there evidence that the quadratic term improves the model fit? Explain your answer.

# %%
df = pd.DataFrame({'y': y, 'x':x})

model13g = smf.ols(formula='y ~ x + I(x**2)', data=df)
results13g = model13g.fit()
print(results13g.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     227.8
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           2.26e-37
# Time:                        12:56:37   Log-Likelihood:                 6.1794
# No. Observations:                 100   AIC:                            -6.359
# Df Residuals:                      97   BIC:                             1.457
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0527      0.028    -38.214      0.000      -1.107      -0.998
# ...

# %%
design = MS([poly('x', degree=2, raw=True)]) # Note the raw argument; this makes it identical to the R-notation formula
X = design.fit_transform(df)

modelMS = sm.OLS(y, X)
resultsMS = modelMS.fit()

print(resultsMS.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     227.8
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           2.26e-37
# Time:                        13:00:02   Log-Likelihood:                 6.1794
# No. Observations:                 100   AIC:                            -6.359
# Df Residuals:                      97   BIC:                             1.457
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
anova_lm(results13, results13g)
# Out:
#    df_resid       ssr  df_diff   ss_diff         F    Pr(>F)
# 0      98.0  5.209812      0.0       NaN       NaN       NaN
# 1      97.0  5.174301      1.0  0.035511  0.665699  0.416554

# %% [markdown]
# Adding the quadradic increases $R^2$ from 0.823 to 0.824, the *p*-valule of the F-statistic being only 0.41. So no, it does not improve the fit significantly.

# %% [markdown]
# **(h)** Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model (3.39) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term ε in (b). Describe your results.

# %%
x = rng.normal(0, 1, size=100)
eps = rng.normal(0, 0.12, size=100)
y = -1 + 0.5 * x + eps

df = pd.DataFrame({'y': y, 'x':x})
model13h = smf.ols(formula='y ~ x', data=df)
results13h = model13h.fit()
print(results13h.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           9.84e-67
# Time:                        13:11:10   Log-Likelihood:                 84.375
# No. Observations:                 100   AIC:                            -164.7
# Df Residuals:                      98   BIC:                            -159.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0006      0.011    -93.731      0.000      -1.022      -0.979
# ...

# %%
fig, ax = subplots(figsize = (5, 5))
ax.scatter(x, y)
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.axline( (x.mean(), y.mean()) , slope = results13h.params[1], color = 'r', label = 'Estimated')
ax.axline( (0, -1) , slope = 0.5, color = 'k', linestyle = '--', label = 'True')
ax.legend(loc="lower right");

# %% [markdown]
# Reducing the variance in the error term increaes fit, and makes coefficient estimates closer to their true values. This is also visible in the plot.

# %% [markdown]
# **(i)** Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model (3.39) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term ε in (b). Describe your results.

# %%
x = rng.normal(0, 1, size=100)
eps = rng.normal(0, 0.50, size=100)
y = -1 + 0.5 * x + eps

df = pd.DataFrame({'y': y, 'x':x})
model13i = smf.ols(formula='y ~ x', data=df)
results13i = model13i.fit()
print(results13i.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     54.98
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           4.40e-11
# Time:                        13:57:30   Log-Likelihood:                -82.806
# No. Observations:                 100   AIC:                             169.6
# Df Residuals:                      98   BIC:                             174.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0364      0.057    -18.274      0.000      -1.149      -0.924
# ...

# %%
fig, ax = subplots(figsize = (5, 5))
ax.scatter(x, y)
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.axline( (x.mean(), y.mean()) , slope = results13i.params[1], color = 'r', label = 'Estimated')
ax.axline( (0, -1) , slope = 0.5, color = 'k', linestyle = '--', label = 'True')
ax.legend(loc="lower right");

# %% [markdown]
# Increasing the variance in the error term reduces fit, and makes coefficient estimates farther to their true values. This is also visible in the plot.

# %% [markdown]
# **(j)** What are the confidence intervals for $ \hat{\beta_0} $ and $ \hat{\beta_1} $ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.

# %%
print(f"Intercept default:", {results13g.params[0] - 1.96**results13g.bse[0]}, {results13g.params[0] + 1.96*results13g.bse[0]})
print(f"Slope default:", {results13g.params[1] - 1.96**results13g.bse[1]}, {results13g.params[1] + 1.96*results13g.bse[1]})

print(f"Intercept less noisy:", {results13h.params[0] - 1.96**results13h.bse[0]}, {results13h.params[0] + 1.96*results13h.bse[0]})
print(f"Slope less noisy:", {results13h.params[1] - 1.96**results13h.bse[1]}, {results13h.params[1] + 1.96*results13h.bse[1]})

print(f"Intercept more noisy:", {results13i.params[0] - 1.96**results13i.bse[0]}, {results13i.params[0] + 1.96*results13i.bse[0]})
print(f"Slope more noisy:", {results13i.params[1] - 1.96**results13i.bse[1]}, {results13i.params[1] + 1.96*results13i.bse[1]})
# Out:
# Intercept default: {-2.071381440915595} {-0.9986788450215021}
# Slope default: {-0.5191813756188441} {0.5422402005325203}
# Intercept less noisy: {-2.007772561412103} {-0.9796403354989649}
# Slope less noisy: {-0.49638281438827414} {0.5339608729502238}
# Intercept more noisy: {-2.0752755595299064} {-0.9252164372594888}
# Slope more noisy: {-0.5821916779633024} {0.5822143005653377}

# %% [markdown]
# The confidence intervals are narrower for the less noisy data, and wider for the noisier data.

# %% [markdown]
# ### (14)

# %% [markdown]
# This problem focuses on the *collinearity* problem.
#
# **(a)** Perform the following commands in `Python`:

# %%
rng = np.random.default_rng(10)
x1 = rng.uniform(0, 1, size=100)
x2 = 0.5 * x1 + rng.normal(size=100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size=100)

# %% [markdown]
# The last line corresponds to creating a linear model in which `y` is a function of `x1` and `x2`. Write out the form of the linear model. What are the regression coefficients?
#
# $$ y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \epsilon $$
#
# $$ y = \beta_0 + \beta_1 x_1 + \beta_2 ( \beta_3 x_1 + \nu ) + \epsilon $$
#
# $$ y = \beta_0 + \beta_1 x_1 + \beta_2 \beta_3 x_1 +\beta_2  \nu  + \epsilon $$
#
# $$ y = \beta_0 + ( \beta_1 + \beta_2 \beta_3 ) x_1 +\beta_2  \nu  + \epsilon $$
#
# $$ y = 2 + ( 2 + 0.3 \cdot 0.5) x_1 + 0.3  \nu  + \epsilon $$
#
# $$ y = 2 + 2.15 x_1 + 0.3  \nu  + \epsilon $$

# %% [markdown]
# **(b)** What is the correlation between `x1` and `x2`? Create a scatterplot displaying the relationship between the variables.

# %%
np.corrcoef(x1, x2)[0,1]
print(f"The correlation between x1 and x2 is {np.corrcoef(x1, x2)[0,1]:.2f}.")
# Out:
# The correlation between x1 and x2 is 0.77.

# %%
fix, ax = subplots(figsize=(5, 5))
ax.scatter(x1, x2)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
# Out:
# Text(0, 0.5, 'x2')

# %% [markdown]
# **(c)** Using this data, fit a least squares regression to predict `y` using `x1` and `x2`. Describe the results obtained. What are $ \hat{\beta}_0 $, $ \hat{\beta}_1 $, and $ \hat{\beta}_2 $? How do these relate to the true $\beta_0$, $\beta_1$, and $\beta_2$? Can you reject the null hypothesis $H_0 : \beta_1 = 0$? How about the null hypothesis $H_0 : \beta_2 = 0$?

# %%
df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})
model14 = smf.ols(formula='y ~ x1 + x2', data=df)
results14 = model14.fit()
print(results14.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           5.76e-08
# Time:                        14:28:18   Log-Likelihood:                -130.62
# No. Observations:                 100   AIC:                             267.2
# Df Residuals:                      97   BIC:                             275.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9579      0.190     10.319      0.000       1.581       2.334
# ...

# %% [markdown]
# $ \hat{\beta}_0 $ and $ \hat{\beta}_1 $ are not too far from true values, but $ \hat{\beta}_2 $ is innacurate. We can reject $ H_0: \beta_1 = 0 $, but not $H_0 : \beta_2 = 0$

# %% [markdown]
# **(d)** Now fit a least squares regression to predict `y` using only `x1`. Comment on your results. Can you reject the null hypothesis $H_0 : \beta_1 = 0$ ?

# %%
df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})
model14d = smf.ols(formula='y ~ x1', data=df)
results14d = model14d.fit()
print(results14d.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           1.37e-08
# Time:                        16:28:51   Log-Likelihood:                -131.28
# No. Observations:                 100   AIC:                             266.6
# Df Residuals:                      98   BIC:                             271.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9371      0.189     10.242      0.000       1.562       2.312
# ...

# %% [markdown]
# Yes, we can reject the null hypothesis $ H_0: \hat{\beta_1} = 0 $, with a *p*-value of < 0.000, smaller than the previous model.

# %% [markdown]
# **(e)** Now fit a least squares regression to predict `y` using only `x2`. Comment on your results. Can you reject the null hypothesis $ H_0: \hat{\beta_1} = 0 $ ?

# %%
df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})
model14d = smf.ols(formula='y ~ x2', data=df)
results14d = model14d.fit()
print(results14d.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     27.99
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           7.43e-07
# Time:                        16:31:56   Log-Likelihood:                -135.24
# No. Observations:                 100   AIC:                             274.5
# Df Residuals:                      98   BIC:                             279.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3239      0.154     15.124      0.000       2.019       2.629
# ...

# %% [markdown]
# Yes, we can also reject the null hypothesis $ H_0: \hat{\beta_1} = 0 $, with a *p*-value of < 0.000, smaller than the initial model.

# %% [markdown]
# **(f)** Do the results obtained in (c)–(e) contradict each other? Explain your answer.
#
# `x2` is insignificant when modeled alongside `x1`, but becomes significant when modeled alone.

# %% [markdown]
# **(g)** Suppose we obtain one additional observation, which was unfor- tunately mismeasured. We use the function `np.concatenate()` to add this additional observation to each of `x1`, `x2` and `y`.

# %%
x1 = np.concatenate([x1, [0.1]])
x2 = np.concatenate([x2, [0.8]])
y = np.concatenate([y, [6]])

# %% [markdown]
# Re-fit the linear models from (c) to (e) using this new data. What effect does this new observation have on the each of the models? In each model, is this observation an outlier? A high-leverage point? Both? Explain your answers.

# %%
df = pd.DataFrame({'y': y, 'x1': x1, 'x2': x2})

# %%
model14g1 = smf.ols(formula='y ~ x1 + x2', data=df)
results14g1 = model14g1.fit()
print(results14g1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           5.76e-08
# Time:                        16:58:19   Log-Likelihood:                -130.62
# No. Observations:                 100   AIC:                             267.2
# Df Residuals:                      97   BIC:                             275.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9579      0.190     10.319      0.000       1.581       2.334
# ...

# %%
model14g2 = smf.ols(formula='y ~ x1', data=df)
results14g2 = model14g2.fit()
print(results14g2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           1.37e-08
# Time:                        16:58:28   Log-Likelihood:                -131.28
# No. Observations:                 100   AIC:                             266.6
# Df Residuals:                      98   BIC:                             271.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9371      0.189     10.242      0.000       1.562       2.312
# ...

# %%
model14g3 = smf.ols(formula='y ~ x2', data=df)
results14g3 = model14g3.fit()
print(results14g3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     27.99
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           7.43e-07
# Time:                        16:58:33   Log-Likelihood:                -135.24
# No. Observations:                 100   AIC:                             274.5
# Df Residuals:                      98   BIC:                             279.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3239      0.154     15.124      0.000       2.019       2.629
# ...

# %% [markdown]
# ### (15)

# %% [markdown]
# This problem involves the `Boston` data set, which we saw in the lab for this chapter. We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.
#
# **(a)** For each predictor, fit a simple linear regression model to predict the response. Describe your results. In which of the models is there a statistically significant association between the predictor and the response? Create some plots to back up your assertions.

# %%
Boston = load_data('boston')
Boston.head()
# Boston.dtypes
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# Every individual predictor is significant (*p*-value < 0.001), except for `chas`, the dummy indicating bording on the Charles River.
#
# Loop form:

# %%
varlist = Boston.columns.drop(['crim'])
varlist

coef = []
pvalues = []

for var in varlist:
    formula = f'crim ~ {var}'
    res = smf.ols(formula=formula, data=Boston).fit()
    print(f"{var:<8} {res.params[1]:>6.2f}  {res.pvalues[1]:.2f}")
    coef.append(res.params[1])
# Out:
# zn        -0.07  0.00
# indus      0.51  0.00
# chas      -1.89  0.21
# nox       31.25  0.00
# rm        -2.68  0.00
# age        0.11  0.00
# dis       -1.55  0.00
# rad        0.62  0.00
# tax        0.03  0.00
# ptratio    1.15  0.00
# lstat      0.55  0.00
# medv      -0.36  0.00

# %% [markdown]
# List comprehension practice

# %%
Boston2 = Boston.copy()
Boston2['zn2'] = [i if i > 10 else 0 for i in Boston2['zn'] ]
Boston2.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv   zn2
# 0   4.98  24.0  18.0
# 1   9.14  21.6   0.0
# 2   4.03  34.7   0.0
# 3   2.94  33.4   0.0
# 4   5.33  36.2   0.0

# %% [markdown]
# **(b)** Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis $ H_0: \beta_j = 0 $ ?

# %%
# regString = ""
# for var in varlist:
#     if var == 'zn':
#         regString = var
#     else:
#         regString = regString + ' + ' + var

regString = " + ".join(varlist)

regString
# Out:
# 'zn + indus + chas + nox + rm + age + dis + rad + tax + ptratio + lstat + medv'

# %%
formula = 'crim ~ ' + regString
res = smf.ols(formula=formula, data=Boston).fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     33.52
# Date:                Mon, 11 Dec 2023   Prob (F-statistic):           2.03e-56
# Time:                        19:10:48   Log-Likelihood:                -1655.4
# No. Observations:                 506   AIC:                             3337.
# Df Residuals:                     493   BIC:                             3392.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.7784      7.082      1.946      0.052      -0.136      27.693
# ...

# %% [markdown]
# We can reject the null for: `zn`, `dis`, `rad`, and `medv`.

# %% [markdown]
# **(c)** How do your results from (a) compare to your results from (b)? Create a plot displaying the univariate regression coefficients from (a) on the x-axis, and the multiple regression coefficients from (b) on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coefficient in a simple linear regression model is shown on the x-axis, and its coefficient estimate in the multiple linear regression model is shown on the y-axis.

# %%
coefMult = [res.params[i] for i in range(1, varlist.shape[0] + 1)]

# %%
fig, ax = subplots(figsize=(5,5))
ax.scatter(coef, coefMult)
ax.set_xlabel('Coefficients univariate')
ax.set_ylabel('Coefficients multivariate')
# Out:
# Text(0, 0.5, 'Coefficients multivariate')

# %% [markdown]
# **(d)** Is there evidence of non-linear association between any of the predictors and the response? To answer this question, for each predictor X, fit a model of the form
#
# $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + \beta_3 X^3 + \epsilon $$

# %%
varlist = Boston.columns.drop(['crim', 'chas']) # chas is binary; cannot have higher order polynomials

coef = []
pvalues = []

for var in varlist:
    formula = f'crim ~ {var} + I({var}**2) + I({var}**3)'
    res = smf.ols(formula=formula, data=Boston).fit()
    print(f"{var:>8}    {res.params[1]:>8.2f}  {res.pvalues[1]:.2f}")
    print(f"{var:>8}^2  {res.params[2]:>8.2f}  {res.pvalues[2]:.2f}")
    print(f"{var:>8}^3  {res.params[3]:>8.2f}  {res.pvalues[3]:.2f}\n")
    coef.append(res.params[1])
# Out:
#       zn       -0.33  0.00
#       zn^2      0.01  0.09
#       zn^3     -0.00  0.23
#
#    indus       -1.97  0.00
#    indus^2      0.25  0.00
#    indus^3     -0.01  0.00
#
#      nox    -1279.37  0.00
#      nox^2   2248.54  0.00
#      nox^3  -1245.70  0.00
#
#       rm      -39.15  0.21
#       rm^2      4.55  0.36
#       rm^3     -0.17  0.51
#
#      age        0.27  0.14
#      age^2     -0.01  0.05
#      age^3      0.00  0.01
#
#      dis      -15.55  0.00
#      dis^2      2.45  0.00
#      dis^3     -0.12  0.00
#
#      rad        0.51  0.62
#      rad^2     -0.08  0.61
#      rad^3      0.00  0.48
#
#      tax       -0.15  0.11
#      tax^2      0.00  0.14
#      tax^3     -0.00  0.24
#
#  ptratio      -82.36  0.00
#  ptratio^2      4.64  0.00
#  ptratio^3     -0.08  0.01
#
#    lstat       -0.45  0.33
#    lstat^2      0.06  0.06
#    lstat^3     -0.00  0.13
#
#     medv       -5.09  0.00
#     medv^2      0.16  0.00
#     medv^3     -0.00  0.00

# %% [markdown]
# They all have non-linear features except for `rm`, `rad`, and `tax`.
